# %%
# Load FILE
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-448cbad1-0a62-4d75-be1b-ee7d951476e9" name="files[]" multiple disabled />
#      <output id="result-448cbad1-0a62-4d75-be1b-ee7d951476e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data_hb1_61_83.csv to Data_hb1_61_83.csv
# Saving Data_hb1_84.csv to Data_hb1_84.csv
# Saving Data_hb2_61_83.csv to Data_hb2_61_83.csv
# Saving Data_hb2_84.csv to Data_hb2_84.csv

# %%
# Seed value
seed_value= 0
import os
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import tensorflow as tf
tf.set_random_seed(seed_value
                   
import time
import datetime
import pandas as pd
import matplotlib.pyplot as plt
from datetime import timedelta
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler

dataset = pd.read_csv('Data_hb1_61_83.csv', header=0, index_col=0)
data_org = dataset.iloc[:, :].values

# Case HB1_1d
input_dim = data_org.shape[1]                 
output_dim = 1
seq_length = 10                                
num_units = 20                                  
num_cells = 1                                  
learning_rate = 0.0001                           
keep_prob = 0.7                                
size_train = 6574                              # Valid 1979-1983  (Good)               
data_train = data_org[0 : size_train]
data_valid = data_org[size_train : len(data_org)]
scaler = MinMaxScaler()
train_data = scaler.fit_transform(data_train)
valid_data = scaler.transform(data_valid)
n = 1                                          
def split_data(x_data):
    dataX = []
    dataY = []
    y_data = x_data[:, [-1]]
    for i in range(seq_length, len(y_data) - (n-1)):
        _x = x_data[i - seq_length : i]
        _y = y_data[i + (n-1)] 
        dataX.append(_x)
        dataY.append(_y)
    return dataX, dataY
trainX, trainY = split_data(train_data)
validX, validY = split_data(valid_data)
# Out:
# Length of raw data is:  (8400, 12)
# Length of input data is:  6564
# Data shape for training is trainX.shape; trainY.shape:  (6564, 10, 12) (6564, 1)
# Data shape for validation is validX.shape; validY.shape:  (1816, 10, 12) (1816, 1)

# %%
X = tf.placeholder(tf.float32, [None, seq_length, input_dim])
Y = tf.placeholder(tf.float32, [None, 1])
cell = tf.contrib.rnn.LSTMCell(num_units)
is_training = tf.placeholder_with_default(False, shape=(), name='is_training')
keep_prob = tf.cond(is_training, lambda:tf.constant(keep_prob), lambda:tf.constant(1.0))
cell = tf.contrib.rnn.DropoutWrapper(cell, input_keep_prob = keep_prob)
multi_cell = tf.contrib.rnn.MultiRNNCell([cell] * num_cells, state_is_tuple=True)
multi_cell = tf.contrib.rnn.DropoutWrapper(multi_cell, output_keep_prob = keep_prob)
outputs, states = tf.nn.dynamic_rnn(multi_cell, X, dtype=tf.float32)
Y_pred = tf.contrib.layers.fully_connected(outputs[:,-1], output_dim, activation_fn = None)

loss = tf.reduce_mean(tf.square(Y_pred - Y))
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)
targets = tf.placeholder(tf.float32, [None, 1])
predictions = tf.placeholder(tf.float32, [None, 1])
rmse = tf.sqrt(tf.reduce_mean(tf.square(targets - predictions)))
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-2-1b7231b1669a>:8: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-2-1b7231b1669a>:18: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-2-1b7231b1669a>:22: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/tensor_array_ops.py:162: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn_cell_impl.py:1259: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# X: Tensor("Placeholder:0", shape=(?, 10, 12), dtype=float32)
# Y: Tensor("Placeholder_1:0", shape=(?, 1), dtype=float32)
# OK

# %%
# Create a Saver
saver = tf.train.Saver()
save_dir = 'hb1_1d.20/'
model_name = 'hb1_1d.20'

if not os.path.exists(save_dir):
    os.makedirs(save_dir)
save_path = os.path.join(save_dir, model_name)       
train_loss_summary = []               
valid_loss_summary = []               
train_pred = '' 
valid_pred = ''                       

# Start the session and initialized variables. Variables needs to be initialized
sess = tf.Session()
init_op = tf.global_variables_initializer()
sess.run(init_op)
best_valid_loss = 1                 
best_train_loss = 1
last_improvement = 0                  
require_improvement = 2000            
total_iterations = 0
# Out:
# OK

# %%
def optimize(num_epochs):
    global total_iterations           # Ensure we update the global variables rather than local copies.
    global best_train_loss
    global best_valid_loss
    global last_improvement
    start_time = time.time()            
    for epoch in range(num_epochs):
        total_iterations += 1
        sess.run(optimizer, feed_dict={X: trainX, Y: trainY})
        train_pred = sess.run(Y_pred, feed_dict={X: trainX})
        train_loss = sess.run(rmse, feed_dict={targets: trainY, predictions: train_pred})
        train_loss_summary.append(train_loss)       
        valid_pred = sess.run(Y_pred, feed_dict={X: validX})
        valid_loss = sess.run(rmse, feed_dict={targets: validY, predictions: valid_pred})
        valid_loss_summary.append(valid_loss)
        if valid_loss < best_valid_loss:
            best_valid_loss = valid_loss    
            last_improvement = total_iterations    
            saver.save(sess, save_path, global_step = total_iterations)                              
            improved_str = '*'                     
        else:
            improved_str = ''                     
        if (total_iterations % 100 == 0) or (epoch == (num_epochs - 1)):
            msg = "Iter: {0:>6}, Training Loss: {1:>6.8}, Validation Loss: {2:>6.8} {3}"
            print(msg.format(epoch + 1, train_loss, valid_loss, improved_str))
        if total_iterations - last_improvement > require_improvement:
            print("No improvement found in a while, stopping optimization.")
            break                        
    end_time = time.time()                         
    time_dif = end_time - start_time               
    print("Time usage: " + str(timedelta(seconds=int(round(time_dif)))))
    print('Total training time is ', time_dif, '(s)')
print('OK')
# Out:
# OK

# %%
# RUN MODEL
num_epochs = 100000
optimize(num_epochs)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Iter:    100, Training Loss: 0.037245452, Validation Loss: 0.028878519 *
# Iter:    200, Training Loss: 0.033775177, Validation Loss: 0.02685374 *
# Iter:    300, Training Loss: 0.031161426, Validation Loss: 0.025013436 *
# Iter:    400, Training Loss: 0.028860902, Validation Loss: 0.023370758 *
# Iter:    500, Training Loss: 0.026824946, Validation Loss: 0.021896137 *
# Iter:    600, Training Loss: 0.025008116, Validation Loss: 0.020557087 *
# Iter:    700, Training Loss: 0.023398576, Validation Loss: 0.019354228 *
# Iter:    800, Training Loss: 0.022005474, Validation Loss: 0.018308619 *
# Iter:    900, Training Loss: 0.020826565, Validation Loss: 0.017432813 *
# Iter:   1000, Training Loss: 0.019835031, Validation Loss: 0.016710777 *
# Iter:   1100, Training Loss: 0.018992653, Validation Loss: 0.016104955 *
# Iter:   1200, Training Loss: 0.018264743, Validation Loss: 0.015575975 *
# Iter:   1300, Training Loss: 0.017624974, Validation Loss: 0.015095308 *
# Iter:   1400, Training Loss: 0.01705486, Validation Loss: 0.014647626 *
# Iter:   1500, Training Loss: 0.016542364, Validation Loss: 0.014228147 *
# Iter:   1600, Training Loss: 0.016080027, Validation Loss: 0.013838471 *
# Iter:   1700, Training Loss: 0.0156624, Validation Loss: 0.013482284 *
# Iter:   1800, Training Loss: 0.015283661, Validation Loss: 0.013161764 *
# Iter:   1900, Training Loss: 0.014936591, Validation Loss: 0.012875603 *
# Iter:   2000, Training Loss: 0.014612973, Validation Loss: 0.012618809 *
# Iter:   2100, Training Loss: 0.014304572, Validation Loss: 0.012384055 *
# Iter:   2200, Training Loss: 0.014003993, Validation Loss: 0.01216345 *
# Iter:   2300, Training Loss: 0.013705146, Validation Loss: 0.01194989 *
# Iter:   2400, Training Loss: 0.013403668, Validation Loss: 0.011737863 *
# Iter:   2500, Training Loss: 0.013097554, Validation Loss: 0.011524043 *
# Iter:   2600, Training Loss: 0.012788163, Validation Loss: 0.011307967 *
# Iter:   2700, Training Loss: 0.012481067, Validation Loss: 0.011092742 *
# Iter:   2800, Training Loss: 0.012185605, Validation Loss: 0.010885027 *
# Iter:   2900, Training Loss: 0.011912215, Validation Loss: 0.010693217 *
# Iter:   3000, Training Loss: 0.011668284, Validation Loss: 0.010523919 *
# Iter:   3100, Training Loss: 0.011455467, Validation Loss: 0.010379092 *
# Iter:   3200, Training Loss: 0.01127057, Validation Loss: 0.010256349 *
# Iter:   3300, Training Loss: 0.011108528, Validation Loss: 0.01015155 *
# Iter:   3400, Training Loss: 0.01096467, Validation Loss: 0.010060788 *
# Iter:   3500, Training Loss: 0.010835367, Validation Loss: 0.0099808453 *
# Iter:   3600, Training Loss: 0.010717826, Validation Loss: 0.0099090301 *
# Iter:   3700, Training Loss: 0.010609789, Validation Loss: 0.0098430812 *
# Iter:   3800, Training Loss: 0.010509365, Validation Loss: 0.0097811874 *
# Iter:   3900, Training Loss: 0.010414998, Validation Loss: 0.0097220391 *
# Iter:   4000, Training Loss: 0.010325559, Validation Loss: 0.0096641965 *
# Iter:   4100, Training Loss: 0.01024076, Validation Loss: 0.0096107339 *
# Iter:   4200, Training Loss: 0.010159848, Validation Loss: 0.0095586563 *
# Iter:   4300, Training Loss: 0.010082354, Validation Loss: 0.0095046628 *
# Iter:   4400, Training Loss: 0.010007421, Validation Loss: 0.0094604436 *
# Iter:   4500, Training Loss: 0.0099351397, Validation Loss: 0.0094148507
# Iter:   4600, Training Loss: 0.0098656137, Validation Loss: 0.0093714511 *
# Iter:   4700, Training Loss: 0.0097977966, Validation Loss: 0.0093311574
# Iter:   4800, Training Loss: 0.0097321095, Validation Loss: 0.0092914309 *
# Iter:   4900, Training Loss: 0.0096680755, Validation Loss: 0.0092555285
# Iter:   5000, Training Loss: 0.0096057141, Validation Loss: 0.00922086 *
# Iter:   5100, Training Loss: 0.0095446464, Validation Loss: 0.0091873975 *
# Iter:   5200, Training Loss: 0.0094852634, Validation Loss: 0.0091596292 *
# Iter:   5300, Training Loss: 0.0094263153, Validation Loss: 0.0091314903 *
# Iter:   5400, Training Loss: 0.0093686068, Validation Loss: 0.0091063473 *
# Iter:   5500, Training Loss: 0.0093113286, Validation Loss: 0.0090830401
# Iter:   5600, Training Loss: 0.0092549073, Validation Loss: 0.0090617659 *
# Iter:   5700, Training Loss: 0.0091993567, Validation Loss: 0.009037327 *
# Iter:   5800, Training Loss: 0.009143373, Validation Loss: 0.0090260413 *
# Iter:   5900, Training Loss: 0.0090880711, Validation Loss: 0.0090139871
# Iter:   6000, Training Loss: 0.0090334686, Validation Loss: 0.0089994259 *
# Iter:   6100, Training Loss: 0.0089792768, Validation Loss: 0.0089859162 *
# Iter:   6200, Training Loss: 0.0089254081, Validation Loss: 0.008982528
# Iter:   6300, Training Loss: 0.0088731721, Validation Loss: 0.0089860484
# Iter:   6400, Training Loss: 0.0088202283, Validation Loss: 0.0089754518
# Iter:   6500, Training Loss: 0.0087719262, Validation Loss: 0.008965455 *
# Iter:   6600, Training Loss: 0.0087187458, Validation Loss: 0.0089767128
# Iter:   6700, Training Loss: 0.0086694751, Validation Loss: 0.0089769261
# Iter:   6800, Training Loss: 0.008621295, Validation Loss: 0.0089846291
# Iter:   6900, Training Loss: 0.0085736923, Validation Loss: 0.0089906482
# Iter:   7000, Training Loss: 0.0085271271, Validation Loss: 0.0089970054
# Iter:   7100, Training Loss: 0.0084808087, Validation Loss: 0.0090043321
# Iter:   7200, Training Loss: 0.0084352437, Validation Loss: 0.0090127392
# Iter:   7300, Training Loss: 0.0083898949, Validation Loss: 0.0090210559
# Iter:   7400, Training Loss: 0.008344817, Validation Loss: 0.0090286341
# Iter:   7500, Training Loss: 0.0083002206, Validation Loss: 0.0090408344
# Iter:   7600, Training Loss: 0.0082571935, Validation Loss: 0.0090618534
# Iter:   7700, Training Loss: 0.0082115969, Validation Loss: 0.0090644602
# Iter:   7800, Training Loss: 0.0081686256, Validation Loss: 0.0090729184
# Iter:   7900, Training Loss: 0.008124792, Validation Loss: 0.0090929773
# Iter:   8000, Training Loss: 0.0080854585, Validation Loss: 0.0091236047
# Iter:   8100, Training Loss: 0.0080402503, Validation Loss: 0.0091271186
# Iter:   8200, Training Loss: 0.0080033327, Validation Loss: 0.0091375941
# Iter:   8300, Training Loss: 0.0079585668, Validation Loss: 0.0091668479
# Iter:   8400, Training Loss: 0.0079185525, Validation Loss: 0.009189371
# Iter:   8500, Training Loss: 0.0078797629, Validation Loss: 0.0092113707
# No improvement found in a while, stopping optimization.
# Model saved in path: hb1_1d.20/
# Train_loss: 0.007879378, Valid_loss: 0.009211882
# Min_train_loss: 0.007879378, Min_valid_loss: 0.008965455
# Time usage: 0:29:12
# Total training time is  1752.4137253761292 (s)
# Training time per epoch is  0.017524137253761292 (s)
# CASE hb1_1d.20

# %%
#Plot the training and validation process
# %matplotlib inline
plt.figure(num = 1, figsize = (15,5))
plt.plot(train_loss_summary, '--', label = 'train_loss')
plt.plot(valid_loss_summary, label = 'valid_loss')
plt.title('The Change of Loss Function Values in training and validation process')
plt.legend()
plt.xlim(0)
plt.ylim(0)
plt.xlabel('The Number of Epochs')
plt.ylabel('Loss Function')
plt.show()
# Out:
# The last epoch:  6500

# %%
saver = tf.train.Saver()
save_dir = 'hb1_1d.20/'
model_name = 'hb1_1d.20-6500'
save_path = os.path.join(save_dir, model_name)  
saver.restore(sess, save_path)   
print('OK')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from hb1_1d.20/hb1_1d.20-6500
# OK

# %%
valid_pred = sess.run(Y_pred, feed_dict={X: validX})
data_recover = np.concatenate((valid_data[seq_length+(n-1) :, 0: (input_dim - 1)], valid_pred), axis=1)
data_invert = scaler.inverse_transform(data_recover)
org_valid_pred = data_invert[:, [-1]]                           
org_validY = data_valid[seq_length+(n-1) :, [-1]]
NSE_valid = 100*r2_score(org_validY, org_valid_pred)
MAE_valid = mean_absolute_error(org_validY, org_valid_pred)
RMSE_valid = np.sqrt(mean_squared_error(org_validY, org_valid_pred))
print("MAE for Validation dataset: {}".format(np.around(MAE_valid, decimals = 3)), '(m3/s)')
print('RMSE for Validation dataset: %.3f' % RMSE_valid, '(m3/s)')   
print("NSE for Validation dataset: {}%".format(np.around(NSE_valid, decimals = 2)))

# Plot Validation data
plt.figure(num = 2, figsize = (15,6))
plt.plot(org_validY, '--', label = 'valid_observation')
plt.plot(org_valid_pred, label = 'valid_prediction')
plt.title('Comparison between observed and predicted data in validation stage')
plt.legend()
plt.xlim(0)
plt.ylim()
plt.xlabel('Time step (daily)')
plt.ylabel('Discharge (m3/s)')
plt.show()
np.savetxt('hb1_1d.20/KQ_1 Actual.csv', org_validY, delimiter='\n')
np.savetxt('hb1_1d.20/KQ_1.20 Predict.csv', org_valid_pred, delimiter='\n')
print('OK')
# Out:
# (1816, 1)
# (1826, 12)
# [416.]
# [422.67527845]
# MAE for Validation dataset: 68.12 (m3/s)
# RMSE for Validation dataset: 149.607 (m3/s)
# NSE for Validation dataset: 99.15%
# OK

# %%
# *** CREATE a data file FOR FORECASTING ***
dataset_pred = pd.read_csv('Data_hb1_84.csv', header=0, index_col=0)
data_pred = dataset_pred.iloc[:, :].values                  
pred_data = scaler.transform(data_pred)
predX, predY = split_data(pred_data)

# Forecast 
pred_Z = sess.run(Y_pred, feed_dict = {X: predX})
pred_recover = np.concatenate((pred_data[seq_length+(n-1) :, 0: (input_dim - 1)], pred_Z), axis=1)
pred_invert = scaler.inverse_transform(pred_recover)
Q_pred = pred_invert[:, [-1]]  
Q_orig = data_pred[seq_length+(n-1) :, [-1]]

# Calculating the error on test data
MAE_pred = mean_absolute_error(Q_orig, Q_pred)
RMSE_pred = np.sqrt(mean_squared_error(Q_orig, Q_pred))
NSE_pred = 100*r2_score(Q_orig, Q_pred)
print("MAE for Prediction dataset: {}".format(np.around(MAE_pred, decimals = 3)), '(m3/s)')
print('RMSE for Prediction dataset: %.3f' % RMSE_pred, '(m3/s)')    # 2 ways to show
print("NSE for Prediction dataset: {}%".format(np.around(NSE_pred, decimals = 2)))

# Plot Prediction dataset
# %matplotlib inline
plt.figure(num = 3, figsize = (15,6))
plt.plot(Q_orig, '--', label = 'Q_observation')
plt.plot(Q_pred, label = 'Q_prediction')
plt.title('Comparison between observed and predicted data in peak-flood forecasting')
plt.legend()
plt.xlim(0)
plt.ylim()
plt.xlabel('Time step (daily)')
plt.ylabel('Discharge (m3/s)')
plt.show()
np.savetxt('hb1_1d.20/KQ_pred_1 Actual.csv', Q_orig, delimiter='\n')
np.savetxt('hb1_1d.20/KQ_pred_1.20 Predict.csv', Q_pred, delimiter='\n')
print('FINISH')
# Out:
# Shape of prediction data:  (356, 10, 12)
# (356, 1) (366, 12)
# - Observed peak-flood: Q_orig 10000.00 m3/s
# - Predicted peak-flood: Q_pred 9247.57 m3/s
# MAE for Prediction dataset: 87.061 (m3/s)
# RMSE for Prediction dataset: 151.014 (m3/s)
# NSE for Prediction dataset: 99.11%
# FINISH
